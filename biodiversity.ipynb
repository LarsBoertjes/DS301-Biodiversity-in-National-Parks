# %% [markdown]
# # Biodiversity in National Parks
#
# ## Introduction
# This data analysis is part of the Codecademy Data Scientist career path. This project in particular will focus on cleaning up the data in order to perform analysis on it. The data is from the National Parks Service about endangered species in different parks.
#
#
# The data analysis is composed as follows:
#
# 1. Descriptive analysis of the datasets
# 2. Exploratory data analysis
# 2. Main Questions
# 3. Conclusion
# 4. Appendix
#
# The Main Questions part consists of the following research questions:
# 1. Which park is most biodiverse?
# 2. Which species are endangered?
# 3. What Park has the most endangered species?
# 4. What category of animals is the most endangered?
# 5. Is there a difference in endangerement of endangered species among different parks?
# 6....
#
# Each question will be accompanied by 2 graphs

# %% [markdown]
# ### 1 Initial Data Inspection

# %% [markdown]
# #### 1.1 Importing libraries and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
observations = pd.read_csv('observations.csv')
species = pd.read_csv('species_info.csv')

# %% [markdown]
# #### 1.2 Data inspection

# %%
observations.head()
# Out:
#             scientific_name                            park_name  observations
# 0        Vicia benghalensis  Great Smoky Mountains National Park            68
# 1            Neovison vison  Great Smoky Mountains National Park            77
# 2         Prunus subcordata               Yosemite National Park           138
# 3      Abutilon theophrasti                  Bryce National Park            84
# 4  Githopsis specularioides  Great Smoky Mountains National Park            85

# %%
observations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23296 entries, 0 to 23295
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   scientific_name  23296 non-null  object
#  1   park_name        23296 non-null  object
#  2   observations     23296 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 546.1+ KB

# %%
species.head()
# Out:
#   category                scientific_name  \
# 0   Mammal  Clethrionomys gapperi gapperi
# 1   Mammal                      Bos bison
# 2   Mammal                     Bos taurus
# 3   Mammal                     Ovis aries
# 4   Mammal                 Cervus elaphus
#
#                                         common_names conservation_status
# 0                           Gapper's Red-Backed Vole                 NaN
# 1                              American Bison, Bison                 NaN
# 2  Aurochs, Aurochs, Domestic Cattle (Feral), Dom...                 NaN
# 3  Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)                 NaN
# 4                                      Wapiti Or Elk                 NaN

# %%
species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5824 entries, 0 to 5823
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   category             5824 non-null   object
#  1   scientific_name      5824 non-null   object
#  2   common_names         5824 non-null   object
#  3   conservation_status  191 non-null    object
# dtypes: object(4)
# memory usage: 182.1+ KB

# %% [markdown]
# the observation dataset is exactly 4 times the length of the species dataset, which indicates that the observation dataset consists of 4 observations of each species, looking at the number of national parks below, we can conclude that this is in observation per specie in each national park.

# %%
for num, park in enumerate(observations.park_name.unique()):
    print(num+1, park)
# Out:
# 1 Great Smoky Mountains National Park
# 2 Yosemite National Park
# 3 Bryce National Park
# 4 Yellowstone National Park

# %% [markdown]
# #### 1.3 Merging the Data

# %% [markdown]
# We therefore want to merge the data on the scientific_name column to have a complete dataset.

# %%
biodiversity_data = pd.merge(observations, species)

# %%
biodiversity_data.head()
# Out:
#       scientific_name                            park_name  observations  \
# 0  Vicia benghalensis  Great Smoky Mountains National Park            68
# 1  Vicia benghalensis               Yosemite National Park           148
# 2  Vicia benghalensis            Yellowstone National Park           247
# 3  Vicia benghalensis                  Bryce National Park           104
# 4      Neovison vison  Great Smoky Mountains National Park            77
#
#          category                        common_names conservation_status
# 0  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 1  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 2  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 3  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 4          Mammal                       American Mink                 NaN

# %% [markdown]
# #### 1.4 Cleaning the data

# %%
print(len(biodiversity_data[biodiversity_data.duplicated() == True]))
biodiversity_data[biodiversity_data.duplicated() == True].head()
# Out:
# 31
#            scientific_name                            park_name  observations  \
# 1070  Monotropa hypopithys  Great Smoky Mountains National Park            73
# 1071  Monotropa hypopithys  Great Smoky Mountains National Park            73
# 1850        Plantago major  Great Smoky Mountains National Park            90
# 1851        Plantago major  Great Smoky Mountains National Park            90
# 2126  Eleocharis palustris  Great Smoky Mountains National Park            62
#
#             category                                       common_names  \
# 1070  Vascular Plant                         American Pinesap, Pine-Sap
# 1071  Vascular Plant                                            Pinesap
# 1850  Vascular Plant                     Nipple-Seed Plantain, Plantain
# 1851  Vascular Plant  Broadleaf Plantain, Buckhorn Plantain, Common ...
# 2126  Vascular Plant                                         Spike-Rush
#
#      conservation_status
# 1070                 NaN
# 1071                 NaN
# 1850                 NaN
# 1851                 NaN
# 2126                 NaN

# %% [markdown]
# As we can see there are 31 duplicates, this is mainly because of slightly different common_names entries. We will get rid of them.

# %%
biodiversity_data = biodiversity_data.drop_duplicates()

# %%
biodiversity_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25601 entries, 0 to 25631
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scientific_name      25601 non-null  object
#  1   park_name            25601 non-null  object
#  2   observations         25601 non-null  int64
#  3   category             25601 non-null  object
#  4   common_names         25601 non-null  object
#  5   conservation_status  880 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 1.4+ MB

# %%
biodiversity_data.conservation_status.unique()
# Out:
# array([nan, 'Species of Concern', 'Threatened', 'Endangered',
#        'In Recovery'], dtype=object)

# %% [markdown]
# The conservation_status column seems to have a lot of missing data. Looking at the unique values in this column, it is because species with no concern about there conservation have been given a NaN value. We will fill this with a corresponding value.

# %%
biodiversity_data['conservation_status'] = biodiversity_data['conservation_status'].fillna('Not of Concern')

# %%
biodiversity_data.conservation_status.value_counts()
# Out:
# Not of Concern        24721
# Species of Concern      732
# Endangered               80
# Threatened               44
# In Recovery              24
# Name: conservation_status, dtype: int64

# %%
biodiversity_data.describe(include='all')
# Out:
#           scientific_name            park_name  observations        category  \
# count               25601                25601  25601.000000           25601
# unique               5541                    4           NaN               7
# top     Castor canadensis  Bryce National Park           NaN  Vascular Plant
# freq                   36                 6406           NaN           19534
# mean                  NaN                  NaN    142.196477             NaN
# std                   NaN                  NaN     69.901035             NaN
# min                   NaN                  NaN      9.000000             NaN
# 25%                   NaN                  NaN     86.000000             NaN
# 50%                   NaN                  NaN    123.000000             NaN
# 75%                   NaN                  NaN    195.000000             NaN
# max                   NaN                  NaN    321.000000             NaN
#
#               common_names conservation_status
# count                25601               25601
# unique                5504                   5
# top     Brachythecium Moss      Not of Concern
# freq                    28               24721
# mean                   NaN                 NaN
# std                    NaN                 NaN
# min                    NaN                 NaN
# 25%                    NaN                 NaN
# 50%                    NaN                 NaN
# 75%                    NaN                 NaN
# max                    NaN                 NaN

# %% [markdown]
# Looking at the unique values of the scientific_name and the common_names column we see a difference (5541 - 5504 = 40). Every scientific name has to correspond to one common name so let's find out what is wrong here.

# %%
name_s = biodiversity_data.groupby('scientific_name').common_names.count().reset_index()
doubles = name_s[name_s.common_names > 4]
doubles
# Out:
#            scientific_name  common_names
# 104    Agrostis capillaris            16
# 107      Agrostis gigantea            16
# 111     Agrostis mertensii            16
# 116        Agrostis scabra            16
# 118   Agrostis stolonifera            16
# ...                    ...           ...
# 5468      Vireo solitarius            16
# 5481      Vulpia bromoides            16
# 5484         Vulpia myuros            16
# 5485      Vulpia octoflora            16
# 5530          Zizia aptera            16
#
# [274 rows x 2 columns]

# %% [markdown]
# When grouping scientific names and counting their common_names counts they all should return 4, one for every observation per national park. However, quite a few return more than 4. If we pick one out we can see what is going on:

# %%
biodiversity_data[biodiversity_data.scientific_name == 'Vireo solitarius']
# Out:
#         scientific_name                            park_name  observations  \
# 17996  Vireo solitarius                  Bryce National Park           112
# 17997  Vireo solitarius                  Bryce National Park           112
# 17998  Vireo solitarius               Yosemite National Park           153
# 17999  Vireo solitarius               Yosemite National Park           153
# 18000  Vireo solitarius               Yosemite National Park           140
# 18001  Vireo solitarius               Yosemite National Park           140
# 18002  Vireo solitarius            Yellowstone National Park           240
# 18003  Vireo solitarius            Yellowstone National Park           240
# 18004  Vireo solitarius  Great Smoky Mountains National Park            81
# 18005  Vireo solitarius  Great Smoky Mountains National Park            81
# 18006  Vireo solitarius            Yellowstone National Park           233
# 18007  Vireo solitarius            Yellowstone National Park           233
# 18008  Vireo solitarius  Great Smoky Mountains National Park            97
# 18009  Vireo solitarius  Great Smoky Mountains National Park            97
# 18010  Vireo solitarius                  Bryce National Park            84
# 18011  Vireo solitarius                  Bryce National Park            84
#
#       category                       common_names conservation_status
# 17996     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 17997     Bird                  Blue-Headed Vireo      Not of Concern
# 17998     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 17999     Bird                  Blue-Headed Vireo      Not of Concern
# 18000     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 18001     Bird                  Blue-Headed Vireo      Not of Concern
# 18002     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 18003     Bird                  Blue-Headed Vireo      Not of Concern
# 18004     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 18005     Bird                  Blue-Headed Vireo      Not of Concern
# 18006     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 18007     Bird                  Blue-Headed Vireo      Not of Concern
# 18008     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 18009     Bird                  Blue-Headed Vireo      Not of Concern
# 18010     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 18011     Bird                  Blue-Headed Vireo      Not of Concern

# %% [markdown]
# We see that this species has multiple observations counts per national park, and multiple common names. These common names value have additional common names in some of the values, however for the sake of a tidy dataset we only want one. Otherwise the observation count for a specific specie is doubled since it has two rows.

# %%
biodiversity_data = biodiversity_data.drop_duplicates(subset=['scientific_name', 'park_name'])
# After this we only have one observation per scientific and common name

# %%
biodiversity_data[biodiversity_data.scientific_name == 'Vireo solitarius']
# Out:
#         scientific_name                            park_name  observations  \
# 17996  Vireo solitarius                  Bryce National Park           112
# 17998  Vireo solitarius               Yosemite National Park           153
# 18002  Vireo solitarius            Yellowstone National Park           240
# 18004  Vireo solitarius  Great Smoky Mountains National Park            81
#
#       category                       common_names conservation_status
# 17996     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 17998     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 18002     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern
# 18004     Bird  Blue-Headed Vireo, Solitary Vireo      Not of Concern

# %% [markdown]
# We now have an observation for every single specie in every national park.

# %%
biodiversity_data.describe(include='all')
# Out:
#            scientific_name                            park_name  observations  \
# count                22164                                22164  22164.000000
# unique                5541                                    4           NaN
# top     Vicia benghalensis  Great Smoky Mountains National Park           NaN
# freq                     4                                 5541           NaN
# mean                   NaN                                  NaN    142.314835
# std                    NaN                                  NaN     69.885082
# min                    NaN                                  NaN      9.000000
# 25%                    NaN                                  NaN     86.000000
# 50%                    NaN                                  NaN    124.000000
# 75%                    NaN                                  NaN    195.000000
# max                    NaN                                  NaN    321.000000
#
#               category        common_names conservation_status
# count            22164               22164               22164
# unique               7                5229                   5
# top     Vascular Plant  Brachythecium Moss      Not of Concern
# freq             17048                  28               21452
# mean               NaN                 NaN                 NaN
# std                NaN                 NaN                 NaN
# min                NaN                 NaN                 NaN
# 25%                NaN                 NaN                 NaN
# 50%                NaN                 NaN                 NaN
# 75%                NaN                 NaN                 NaN
# max                NaN                 NaN                 NaN

# %% [markdown]
# However, if we perform .describe() again on the dataset we see that the difference has only become larger (5541 - 5529). This is because we also might have common names with multiple scientific names.

# %%
name_c = biodiversity_data.groupby('common_names').scientific_name.count().reset_index()
doubles_c = name_c[name_c.scientific_name > 4]
doubles_c
# Out:
#                  common_names  scientific_name
# 11                     A Moss                8
# 16             A Sedge, Sedge               16
# 79              Alpine Fescue                8
# 105       Alpine Springbeauty                8
# 120         Amblystegium Moss                8
# ...                       ...              ...
# 5173        Yellow Pincushion               12
# 5183           Yellow Warbler                8
# 5197    Yellow-Rumped Warbler                8
# 5199  Yellow-Throated Warbler                8
# 5228             Zygodon Moss                8
#
# [240 rows x 2 columns]

# %%
biodiversity_data[biodiversity_data.common_names == 'Alpine Fescue']
# Out:
#                              scientific_name  \
# 16912                   Festuca brachyphylla
# 16913                   Festuca brachyphylla
# 16914                   Festuca brachyphylla
# 16915                   Festuca brachyphylla
# 19280  Festuca brachyphylla ssp. breviculmis
# 19281  Festuca brachyphylla ssp. breviculmis
# 19282  Festuca brachyphylla ssp. breviculmis
# 19283  Festuca brachyphylla ssp. breviculmis
#
#                                  park_name  observations        category  \
# 16912                  Bryce National Park           121  Vascular Plant
# 16913            Yellowstone National Park           256  Vascular Plant
# 16914  Great Smoky Mountains National Park            66  Vascular Plant
# 16915               Yosemite National Park           133  Vascular Plant
# 19280            Yellowstone National Park           275  Vascular Plant
# 19281               Yosemite National Park           167  Vascular Plant
# 19282  Great Smoky Mountains National Park            65  Vascular Plant
# 19283                  Bryce National Park           106  Vascular Plant
#
#         common_names conservation_status
# 16912  Alpine Fescue      Not of Concern
# 16913  Alpine Fescue      Not of Concern
# 16914  Alpine Fescue      Not of Concern
# 16915  Alpine Fescue      Not of Concern
# 19280  Alpine Fescue      Not of Concern
# 19281  Alpine Fescue      Not of Concern
# 19282  Alpine Fescue      Not of Concern
# 19283  Alpine Fescue      Not of Concern

# %% [markdown]
# So let's also drop duplicates this way around.

# %%
biodiversity_data = biodiversity_data.drop_duplicates(subset=['common_names', 'park_name'])

# %%
biodiversity_data[biodiversity_data.common_names == 'Alpine Fescue']
# Out:
#             scientific_name                            park_name  \
# 16912  Festuca brachyphylla                  Bryce National Park
# 16913  Festuca brachyphylla            Yellowstone National Park
# 16914  Festuca brachyphylla  Great Smoky Mountains National Park
# 16915  Festuca brachyphylla               Yosemite National Park
#
#        observations        category   common_names conservation_status
# 16912           121  Vascular Plant  Alpine Fescue      Not of Concern
# 16913           256  Vascular Plant  Alpine Fescue      Not of Concern
# 16914            66  Vascular Plant  Alpine Fescue      Not of Concern
# 16915           133  Vascular Plant  Alpine Fescue      Not of Concern

# %% [markdown]
# Now if we perform .describe() on biodiversity_data we can see that the count of scientific names aligns with the count of common names.

# %%
biodiversity_data.describe(include='all')
# Out:
#            scientific_name                            park_name  observations  \
# count                20916                                20916  20916.000000
# unique                5229                                    4           NaN
# top     Vicia benghalensis  Great Smoky Mountains National Park           NaN
# freq                     4                                 5229           NaN
# mean                   NaN                                  NaN    142.258701
# std                    NaN                                  NaN     69.892740
# min                    NaN                                  NaN      9.000000
# 25%                    NaN                                  NaN     86.000000
# 50%                    NaN                                  NaN    124.000000
# 75%                    NaN                                  NaN    195.000000
# max                    NaN                                  NaN    321.000000
#
#               category                        common_names conservation_status
# count            20916                               20916               20916
# unique               7                                5229                   5
# top     Vascular Plant  Purple Vetch, Reddish Tufted Vetch      Not of Concern
# freq             16344                                   4               20216
# mean               NaN                                 NaN                 NaN
# std                NaN                                 NaN                 NaN
# min                NaN                                 NaN                 NaN
# 25%                NaN                                 NaN                 NaN
# 50%                NaN                                 NaN                 NaN
# 75%                NaN                                 NaN                 NaN
# max                NaN                                 NaN                 NaN

# %% [markdown]
# ### 2 Exploratory data analysis

# %% [markdown]
# ### 3 Main Questions
# #### 3.1 Which park is most biodiverse?
# What makes a park biodiverse?
# - the number of species in the park

# %%
biodiversity_data.head()
# Out:
#       scientific_name                            park_name  observations  \
# 0  Vicia benghalensis  Great Smoky Mountains National Park            68
# 1  Vicia benghalensis               Yosemite National Park           148
# 2  Vicia benghalensis            Yellowstone National Park           247
# 3  Vicia benghalensis                  Bryce National Park           104
# 4      Neovison vison  Great Smoky Mountains National Park            77
#
#          category                        common_names conservation_status
# 0  Vascular Plant  Purple Vetch, Reddish Tufted Vetch      Not of Concern
# 1  Vascular Plant  Purple Vetch, Reddish Tufted Vetch      Not of Concern
# 2  Vascular Plant  Purple Vetch, Reddish Tufted Vetch      Not of Concern
# 3  Vascular Plant  Purple Vetch, Reddish Tufted Vetch      Not of Concern
# 4          Mammal                       American Mink      Not of Concern

# %%
num_species_park = biodiversity_data.groupby('park_name').observations.sum()
num_species_park
# Out:
# park_name
# Bryce National Park                     517568
# Great Smoky Mountains National Park     387581
# Yellowstone National Park              1295803
# Yosemite National Park                  774531
# Name: observations, dtype: int64

# %% [markdown]
# #### 3.2 Which species are endangered?

# %% [markdown]
# #### 3.3 What park has the most endangered species?

# %% [markdown]
# #### 3.4 What category of animals is the most endangered?

# %% [markdown]
# #### 3.5 Is there a difference in endangerement of species among different parks?
